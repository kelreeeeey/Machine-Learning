# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/HotelRecommender/Hotel_Room_attributes.csv.zip
# Out:
# Archive:  /content/gdrive/MyDrive/HotelRecommender/Hotel_Room_attributes.csv.zip
# replace Hotel_Room_attributes.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Hotel_Room_attributes.csv

# %%
# !unzip /content/gdrive/MyDrive/HotelRecommender/Hotel_details.csv.zip
# Out:
# Archive:  /content/gdrive/MyDrive/HotelRecommender/Hotel_details.csv.zip
# replace Hotel_details.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: Hotel_details.csv

# %%
# !unzip /content/gdrive/MyDrive/HotelRecommender/hotel_price_min_maxFormula.zip
# Out:
# Archive:  /content/gdrive/MyDrive/HotelRecommender/hotel_price_min_maxFormula.zip
# replace hotel_price_min_max - Formula.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: hotel_price_min_max - Formula.csv

# %%
# !unzip /content/gdrive/MyDrive/HotelRecommender/hotels_RoomPrice.csv.zip
# Out:
# Archive:  /content/gdrive/MyDrive/HotelRecommender/hotels_RoomPrice.csv.zip
# replace hotels_RoomPrice.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: hotels_RoomPrice.csv

# %%
# !pip install tensorflow==2.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow==2.1.0 in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.15.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.4.1)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.21.6)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (0.2.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.0.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (3.17.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (0.37.1)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (0.8.1)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.14.1)
# Requirement already satisfied: tensorboard<2.2.0,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (2.1.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.0.8)
# Requirement already satisfied: tensorflow-estimator<2.2.0,>=2.1.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (2.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.1.0) (1.46.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==2.1.0) (3.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.3.7)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.35.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==2.1.0) (1.5.2)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %%
pip install keras==2.3.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras==2.3.1 in /usr/local/lib/python3.7/dist-packages (2.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.3.1) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.3.1) (1.21.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.3.1) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from keras==2.3.1) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from keras==2.3.1) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.3.1) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.3.1) (3.13)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras==2.3.1) (1.5.2)

# %%
import keras
print(keras.__version__)
# Out:
# 2.3.1
# Using TensorFlow backend.

# %%
# !pip install pandas==0.25.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas==0.25.3 in /usr/local/lib/python3.7/dist-packages (0.25.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas==0.25.3) (2022.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from pandas==0.25.3) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas==0.25.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.6.1->pandas==0.25.3) (1.15.0)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 0.25.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers.core import Dense,Activation,Dropout
from keras.layers import LSTM
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from keras.callbacks import EarlyStopping
import math
import os
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Fetching the data

# %%
hotel_details=pd.read_csv('/content/Hotel_details.csv',delimiter=',')
hotel_rooms=pd.read_csv('/content/Hotel_Room_attributes.csv',delimiter=',')
hotel_cost=pd.read_csv('/content/hotels_RoomPrice.csv',delimiter=',')

# %%
hotel_details.head()
# Out:
#       id  hotelid                 hotelname                 address     city  \
# 0  46406  1771651  Mediteran Bungalow Galeb            Vukovarska 7     Omis
# 1  46407   177167             Hotel Polonia        Plac Teatralny 5    Torun
# 2  46408  1771675         Rifugio Sass Bece  Belvedere del Pordoi,1  Canazei
# 3  46409   177168            Madalena Hotel                 Mykonos  Mykonos
# 4  46410  1771718         Pension Morenfeld  Mair im Korn Strasse 2  Lagundo
#
#    country  zipcode   propertytype  starrating   latitude  longitude  Source  \
# 0  Croatia  21310.0  Holiday parks           4  43.440124  16.682505       2
# 1   Poland      NaN         Hotels           3  53.012329  18.603800       5
# 2    Italy  38032.0         Hotels           3  46.477920  11.813350       2
# 3   Greece  84600.0         Hotels           3  37.452316  25.329849       5
# 4    Italy  39022.0         Hotels           3  46.682780  11.131736       2
#
#                                                  url curr
# 0  https://www.booking.com/hotel/hr/bungalow-luxu...  EUR
# 1  https://www.agoda.com/en-gb/hotel-polonia/hote...  EUR
# 2  http://www.booking.com/hotel/it/rifugio-sass-b...  EUR
# 3  https://www.agoda.com/en-gb/madalena-hotel/hot...  EUR
# 4  http://www.booking.com/hotel/it/pension-morenf...  EUR

# %%
hotel_rooms.head()
# Out:
#          id  hotelcode                                      roomamenities  \
# 0  50677497     634876  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 1  50672149    8328096  Air conditioning: ;Closet: ;Fireplace: ;Free W...
# 2  50643430    8323442  Air conditioning: ;Closet: ;Dishwasher: ;Firep...
# 3  50650317       7975  Air conditioning: ;Clothes rack: ;Coffee/tea m...
# 4  50650318       7975  Air conditioning: ;Clothes rack: ;Coffee/tea m...
#
#                roomtype                                    ratedescription
# 0           Double Room       Room size: 15 m²/161 ft², Shower, 1 king bed
# 1         Vacation Home  Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 2         Vacation Home  Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 3  Standard Triple Room    Room size: 20 m²/215 ft², Shower, 3 single beds
# 4  Standard Triple Room    Room size: 20 m²/215 ft², Shower, 3 single beds

# %% [markdown]
# Data Cleaning and transformations

# %%
del hotel_details['id']
del hotel_rooms['id']
del hotel_details['zipcode']

# %%
hotel_details=hotel_details.dropna()
hotel_rooms=hotel_rooms.dropna()

# %%
hotel_details.drop_duplicates(subset='hotelid',keep=False,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hotel=pd.merge(hotel_rooms,hotel_details,left_on='hotelcode',right_on='hotelid',how='inner')

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription', 'hotelid',
#        'hotelname', 'address', 'city', 'country', 'propertytype', 'starrating',
#        'latitude', 'longitude', 'Source', 'url', 'curr'],
#       dtype='object')

# %%
del hotel['hotelid']
del hotel['url']
del hotel['curr']
del hotel['Source']

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription',
#        'hotelname', 'address', 'city', 'country', 'propertytype', 'starrating',
#        'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# Recommender system based only on City and ratings about the hotel

# %%
def citybased(city):
    hotel['city']=hotel['city'].str.lower()
    citybase=hotel[hotel['city']==city.lower()]
    citybase=citybase.sort_values(by='starrating',ascending=False)
    citybase.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    if(citybase.empty==0):
        hname=citybase[['hotelname','starrating','address','roomamenities','ratedescription']]
        return hname.head()
    else:
        print('No Hotels Available')

# %%
print('Top 5 hotels')
citybased('London')
# Out:
# Top 5 hotels
#                                   hotelname  starrating  \
# 48985            The Colonnade London Hotel           4
# 58663    South Point Suites - London Bridge           4
# 106943  Doubletree by Hilton London Chelsea           4
# 57452      Sir Christopher Wren Hotel & Spa           4
# 92479              The Manor Hotel Heathrow           4
#
#                              address  \
# 48985          2 Warrington Crescent
# 58663              Bermondsey Street
# 106943  Imperial Road Imperial Wharf
# 57452                        Unknown
# 92479        Village Green, Datchet,
#
#                                             roomamenities  \
# 48985   Additional toilet: ;Air conditioning: ;Alarm c...
# 58663   Air conditioning: ;Alarm clock: ;Blackout curt...
# 106943  Air conditioning: ;Alarm clock: ;Blackout curt...
# 57452   Air conditioning: ;Alarm clock: ;Bathrobes: ;B...
# 92479   Additional bathroom: ;Additional toilet: ;Air ...
#
#                                           ratedescription
# 48985   Room size: 28 m²/301 ft², Balcony/terrace, Non...
# 58663   Room size: 24 m²/258 ft², Street view, Non-smo...
# 106943  Room size: 20 m²/215 ft², Street view, Non-smo...
# 57452   Room size: 25 m²/269 ft², Non-smoking, Shower ...
# 92479                    Shower and bathtub, 1 double bed

# %%
room_no=[
     ('king',2),
   ('queen',2), 
    ('triple',3),
    ('master',3),
   ('family',4),
   ('murphy',2),
   ('quad',4),
   ('double-double',4),
   ('mini',2),
   ('studio',1),
    ('junior',2),
   ('apartment',4),
    ('double',2),
   ('twin',2),
   ('double-twin',4),
   ('single',1),
     ('diabled',1),
   ('accessible',1),
    ('suite',2),
    ('one',2)
   ]

# %%
def calc():
    guests_no=[]
    for i in range(hotel.shape[0]):
        temp=hotel['roomtype'][i].lower().split()
        flag=0
        for j in range(len(temp)):
            for k in range(len(room_no)):
                if temp[j]==room_no[k][0]:
                    guests_no.append(room_no[k][1])
                    flag=1
                    break
            if flag==1:
                break
        if flag==0:
            guests_no.append(2)
    hotel['guests_no']=guests_no

calc()

# %%
def pop_citybased(city,number):
    hotel['city']=hotel['city'].str.lower()
    popbased=hotel[hotel['city']==city.lower()]
    popbased=popbased[popbased['guests_no']==number].sort_values(by='starrating',ascending=False)
    popbased.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    if popbased.empty==True:
        print('Sorry No Hotels Available\n tune your constraints')
    else:
        return popbased[['hotelname','roomtype','guests_no','starrating','address','roomamenities','ratedescription']].head(10)

# %%
pop_citybased('London',4)
# Out:
#                                              hotelname  \
# 1440                  Holiday Inn London - Heathrow T5
# 53496                   Mercure London Hyde Park Hotel
# 60734     Hallmark Hotel London Chigwell Prince Regent
# 107246  Radisson Blu Edwardian Kenilworth - Bloomsbury
# 55913                              Acorn Lodge Gatwick
# 64171                          Gatwick Cambridge Hotel
# 96611                             Trumbles Gatwick B&B
# 97400                  Heathrow/Windsor Marriott Hotel
# 65811                            Atrium Hotel Heathrow
# 112259                  The Level at Melia White House
#
#                                                 roomtype  guests_no  \
# 1440                                         Family Room          4
# 53496                                        Family Room          4
# 60734                              Executive Family Room          4
# 107246                 Family Room 2 adults + 2 children          4
# 55913                          Family Stay & Park 8 Days          4
# 64171                                        Family Room          4
# 96611   Family Room (2 Adults and 2 Children) - Number 6          4
# 97400     Deluxe Room, Guest room, 2 Double, Family Room          4
# 65811                                           Family 1          4
# 112259                             The Level Family Room          4
#
#         starrating                        address  \
# 1440             4                  Old Bath Road
# 53496            4             8-14 Talbot Square
# 60734            4                     Manor Road
# 107246           4        97 Great Russell Street
# 55913            4       79 Massetts Road, Horley
# 64171            4      19 Bonehurst Road, Horley
# 96611            4                      Stan Hill
# 97400            4           Ditton Road, Langley
# 65811            4  Great south-west road Feltham
# 112259           4                  Albany Street
#
#                                             roomamenities  \
# 1440    Air conditioning: ;Alarm clock: ;Blackout curt...
# 53496   Air conditioning: ;Desk: ;Free Wi-Fi in all ro...
# 60734   Air conditioning: ;Carpeting: ;Closet: ;Clothe...
# 107246  Air conditioning: ;Alarm clock: ;Bathrobes: ;C...
# 55913   Air conditioning: ;Carpeting: ;Closet: ;Coffee...
# 64171   Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 96611   Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 97400   Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 65811   Additional toilet: ;Air conditioning: ;Alarm c...
# 112259  Air conditioning: ;Bathrobes: ;Blackout curtai...
#
#                                           ratedescription
# 1440    Room size: 25 m²/269 ft², Non-smoking, Separat...
# 53496   Room size: 31 m²/334 ft², Non-smoking, 1 singl...
# 60734       Non-smoking, Shower and bathtub, 1 double bed
# 107246  Room size: 20 m²/215 ft², Non-smoking, Shower ...
# 55913                 Shower, 1 double bed and 1 bunk bed
# 64171   Room size: 15 m²/161 ft², Non-smoking, Shower ...
# 96611   Room size: 18 m²/194 ft², Shower and bathtub, ...
# 97400   Room size: 30 m²/323 ft², Non-smoking, Shower ...
# 65811   Room size: 28 m²/301 ft², Shower, 2 single bed...
# 112259  Shower and bathtub, Executive lounge access, 1...

# %%
hotel['roomamenities']=hotel['roomamenities'].str.replace(': ;',',')

# %%
def requirementbased(city,number,features):
    hotel['city']=hotel['city'].str.lower()
    hotel['roomamenities']=hotel['roomamenities'].str.lower()
    features=features.lower()
    features_tokens=word_tokenize(features)  
    sw = stopwords.words('english')
    lemm = WordNetLemmatizer()
    f1_set = {w for w in features_tokens if not w in sw}
    f_set=set()
    for se in f1_set:
        f_set.add(lemm.lemmatize(se))
    reqbased=hotel[hotel['city']==city.lower()]
    reqbased=reqbased[reqbased['guests_no']==number]
    reqbased=reqbased.set_index(np.arange(reqbased.shape[0]))
    l1 =[];l2 =[];cos=[];
    #print(reqbased['roomamenities'])
    for i in range(reqbased.shape[0]):
        temp_tokens=word_tokenize(reqbased['roomamenities'][i])
        temp1_set={w for w in temp_tokens if not w in sw}
        temp_set=set()
        for se in temp1_set:
            temp_set.add(lemm.lemmatize(se))
        rvector = temp_set.intersection(f_set)
        #print(rvector)
        cos.append(len(rvector))
    reqbased['similarity']=cos
    reqbased=reqbased.sort_values(by='similarity',ascending=False)
    reqbased.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    return reqbased[['hotelname','roomtype','guests_no','starrating','address','roomamenities','ratedescription','similarity']].head(10)

# %% [markdown]
# Requirement And special needs based Recommender

# %%
requirementbased('London',1,'I need a extra toilet and room should be completely air conditioned.I should have a bathrobe.')
# Out:
#                                 hotelname                   roomtype  \
# 310            The Colonnade London Hotel                     Studio
# 819              Amba Hotel Charing Cross          Studio King Suite
# 793        Holiday Inn Express Park Royal  2 Single Beds Non-smoking
# 816           Simply Rooms & Suites Hotel        Deluxe Studio Suite
# 912                   The Cleveland Hotel        Single Room - Basic
# 408    South Point Suites - London Bridge        Deluxe Studio Suite
# 883                           Angus Hotel       Single - Non-Smoking
# 462  Pestana Chelsea Bridge Hotel And Spa    Accessible Twin Bedroom
# 494            Park Plaza London Waterloo                Studio King
# 323              Park International Hotel       Standard Single Room
#
#      guests_no  starrating                   address  \
# 310          1           4     2 Warrington Crescent
# 819          1           4                The Strand
# 793          1           3  Victoria RoadNorth Acton
# 816          1           4          21 Avonmore Road
# 912          1           4    39-40 Cleveland Square
# 408          1           4         Bermondsey Street
# 883          1           2       31-32 Argyle square
# 462          1           4       354 Queenstown Road
# 494          1           4           6 Hercules Road
# 323          1           4     117-129 Cromwell Road
#
#                                          roomamenities  \
# 310  additional toilet,air conditioning,alarm clock...
# 819  air conditioning,alarm clock,bathrobes,carpeti...
# 793  air conditioning,alarm clock,carpeting,closet,...
# 816  additional toilet,air conditioning,cleaning pr...
# 912  air conditioning,carpeting,closet,clothes rack...
# 408  additional bathroom,additional toilet,air cond...
# 883  additional toilet,air conditioning,carpeting,c...
# 462  air conditioning,alarm clock,bathrobes,blackou...
# 494  air conditioning,alarm clock,bathrobes,blackou...
# 323  additional toilet,air conditioning,blackout cu...
#
#                                        ratedescription  similarity
# 310  Room size: 28 m²/301 ft², Balcony/terrace, Non...           4
# 819  Room size: 34 m²/366 ft², Non-smoking, Shower ...           3
# 793  Room size: 25 m²/269 ft², Non-smoking, Shower,...           3
# 816  Room size: 20 m²/215 ft², City view, Non-smoki...           3
# 912  Room size: 14 m²/151 ft², Non-smoking, Shower,...           3
# 408  Room size: 45 m²/484 ft², 2 bathrooms, Shower,...           3
# 883     Street view, Non-smoking, Shower, 1 double bed           3
# 462  Room size: 30 m²/323 ft², City view, Non-smoki...           3
# 494  Room size: 24 m²/258 ft², City view, Non-smoki...           3
# 323  Room size: 11 m²/118 ft², Non-smoking, Shower,...           3

# %%
from math import sin, cos, sqrt, atan2, radians
import requests
R=6373.0#Earth's Radius
sw = stopwords.words('english')
lemm = WordNetLemmatizer()
def hybrid(address,city,number,features):
    features=features.lower()
    features_tokens=word_tokenize(features)
    f1_set = {w for w in features_tokens if not w in sw}
    f_set=set()
    for se in f1_set:
        f_set.add(lemm.lemmatize(se))
    data = {
    'key': '4519d076b432f5',
    'q': address,
    'format': 'json'}
    response = requests.get(url, params=data)
    dist=[]
    lat1,long1=response.json()[0]['lat'],response.json()[0]['lon']
    lat1=radians(float(lat1))
    long1=radians(float(long1))
    hybridbase=hotel[hotel['guests_no']==number]
    hybridbase['city']=hybridbase['city'].str.lower()
    hybridbase=hybridbase[hybridbase['city']==city.lower()]
    hybridbase.drop_duplicates(subset='hotelcode',inplace=True,keep='first')
    hybridbase=hybridbase.set_index(np.arange(hybridbase.shape[0]))
    for i in range(hybridbase.shape[0]):
        lat2=radians(hybridbase['latitude'][i])
        long2=radians(hybridbase['longitude'][i])
        dlon = long2 - long1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = R * c
        dist.append(distance)
    hybridbase['distance']=dist
    hybridbase=hybridbase.sort_values(by='distance',ascending=True)
    hybridbase=hybridbase.head(15)
    hybridbase=hybridbase.set_index(np.arange(hybridbase.shape[0]))
    coss=[]
    for i in range(hybridbase.shape[0]):
        temp_tokens=word_tokenize(hybridbase['roomamenities'][i])
        temp1_set={w for w in temp_tokens if not w in sw}
        temp_set=set()
        for se in temp1_set:
            temp_set.add(lemm.lemmatize(se))
        rvector = temp_set.intersection(f_set)
        coss.append(len(rvector))
    hybridbase['similarity']=coss
    return hybridbase.sort_values(by='similarity',ascending=False).head(10)

# %%
url = "https://us1.locationiq.com/v1/search.php"
hybrid("Big Ben,London",'London',4,'I need a extra toilet and room should be completely air conditioned.I should have a bathrobe.')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     hotelcode                                      roomamenities  \
# 0       79139  air conditioning,bathrobes,carpeting,closet,co...
# 4      127330  additional toilet,air conditioning,alarm clock...
# 14     175494  air conditioning,alarm clock,bathrobes,blackou...
# 1      127425  air conditioning,closet,coffee/tea maker,fan,f...
# 2       84774  air conditioning,coffee/tea maker,daily housek...
# 3      127426  air conditioning,alarm clock,carpeting,closet,...
# 5      466492  air conditioning,coffee/tea maker,desk,free wi...
# 7      148905  air conditioning,closet,coffee/tea maker,daily...
# 8       84263  air conditioning,blackout curtains,closet,coff...
# 9     1134132  air conditioning,closet,clothes rack,coffee/te...
#
#                            roomtype  \
# 0         St James Family King Room
# 4               Deluxe Family Suite
# 14               Deluxe Family Room
# 1                         Quad Room
# 2                Standard Quad Room
# 3   Superior Family Room (3 Adults)
# 5                         Quad Room
# 7             Westminster Apartment
# 8                              Quad
# 9                Family Double Room
#
#                                       ratedescription  \
# 0   Room size: 35 m²/377 ft², Shower and bathtub, ...
# 4   Room size: 35 m²/377 ft², Non-smoking, 3 bathr...
# 14  Room size: 30 m²/323 ft², Non-smoking, Separat...
# 1   Room size: 20 m²/215 ft², Shower, 2 single bed...
# 2   Room size: 20 m²/215 ft², Balcony/terrace, Non...
# 3   Room size: 17 m²/183 ft², Balcony/terrace, Non...
# 5   Room size: 23 m²/248 ft², Non-smoking, Shower,...
# 7   Room size: 33 m²/355 ft², Street view, Non-smo...
# 8   Non-smoking, Shower, 2 single beds and 1 doubl...
# 9        Room size: 15 m²/161 ft², Shower, 1 bunk bed
#
#                                hotelname                             address  \
# 0                The Trafalgar St. James  2 Spring Gardens, Trafalgar Square
# 4       Mornington Hotel London Victoria                25 Gloucester Street
# 14  Pestana Chelsea Bridge Hotel And Spa                 354 Queenstown Road
# 1                  Melbourne House Hotel                    79 Belgrave Road
# 2                          Huttons Hotel                 53-57 Belgrave Road
# 3                             The Melita                 35 Charlwood Street
# 5               St Georges Pimlico Hotel                115 St Georges Drive
# 7                   Georgian House Hotel              37-39 St Georges Drive
# 8                    The Grapevine Hotel                     117 Warwick Way
# 9                       The Z Hotel City                  23-28 Fleet Street
#
#       city         country propertytype  starrating   latitude  longitude  \
# 0   london  United Kingdom       Hotels           4  51.507397  -0.129185
# 4   london  United Kingdom       Hotels           4  51.490303  -0.140295
# 14  london  United Kingdom       Hotels           4  51.482426  -0.148745
# 1   london  United Kingdom       Hotels           3  51.490276  -0.137371
# 2   london  United Kingdom       Hotels           3  51.490608  -0.138419
# 3   london  United Kingdom       Hotels           3  51.490173  -0.138874
# 5   london  United Kingdom       Hotels           3  51.488531  -0.139517
# 7   london  United Kingdom       Hotels           4  51.490524  -0.143872
# 8   london  United Kingdom       Hotels           2  51.490773  -0.144941
# 9   london  United Kingdom       Hotels           4  51.514295  -0.107946
#
#     guests_no  distance  similarity
# 0           4  0.811211           3
# 4           4  1.586945           3
# 14          4  2.631862           3
# 1           4  1.457966           2
# 2           4  1.474883           2
# 3           4  1.532155           2
# 5           4  1.702462           2
# 7           4  1.749995           2
# 8           4  1.789963           2
# 9           4  1.901806           2

# %%
hotel_cost.head()
#onsite rate is one important feature which could be useful to recommend
#we will drop the rest since it is present in other table and we are going to merge the 
hotel_cost=hotel_cost.drop(['id','refid','websitecode','dtcollected','ratedate','los','guests','roomtype','netrate','ratedescription','ratetype','sourceurl','roomamenities'
,'ispromo','closed','discount','promoname','status_code','taxstatus','taxtype','taxamount','proxyused','israteperstay','hotelblock','input_dtcollected'],axis=1)

# %%
hotel_cost.columns
# Out:
# Index(['hotelcode', 'onsiterate', 'currency', 'maxoccupancy',
#        'mealinclusiontype'],
#       dtype='object')

# %%
#To reccomend we are gonna check how much does the price vary from room to room if 
#the varience is small enough then it is better for them to recommend the hotel
hot=hotel_cost.groupby(['hotelcode','maxoccupancy'])

# %%
hotel_cost.sort_values(by=['onsiterate'],ascending=False)
hotel_cost=hotel_cost.drop_duplicates(subset=['hotelcode','maxoccupancy'],keep='first')

# %%
var=hot['onsiterate'].var().to_frame('varience')
l=[]
for i in range(hotel_cost.shape[0]):
    var1=var[var.index.get_level_values(0)==hotel_cost.iloc[i][0]]
    l.append(var1[var1.index.get_level_values(1)==hotel_cost.iloc[i][3]]['varience'][0])

# %%
hotel_cost['var']=l
hotel_cost=hotel_cost.fillna(0)
hotel_cost['mealinclusiontype']=hotel_cost['mealinclusiontype'].replace(0,'No Complimentary')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
hotel1=pd.merge(hotel,hotel_cost,left_on=['hotelcode','guests_no'],right_on=['hotelcode','maxoccupancy'],how='inner')

# %%
hotel1=hotel1.drop_duplicates(subset=['hotelcode','maxoccupancy'],keep='first')

# %%
hotel1.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription',
#        'hotelname', 'address', 'city', 'country', 'propertytype', 'starrating',
#        'latitude', 'longitude', 'guests_no', 'onsiterate', 'currency',
#        'maxoccupancy', 'mealinclusiontype', 'var'],
#       dtype='object')

# %% [markdown]
# Recommender with pricing included

# %%
def pricing(address,city,number,features):
    h=hybrid(address,city,number,features)
    price_based=pd.merge(h,hotel_cost,left_on=['hotelcode','guests_no'],right_on=['hotelcode','maxoccupancy'],how='inner')
    del price_based['maxoccupancy']
    h=price_based.sort_values(by='var')
    return h.head()

# %%
pricing("Tower of London",'London',4,'I need an alarm clock and a kettle flask.')
#the description is just only for example.It portrays you can keep any specific request
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    hotelcode                                      roomamenities  \
# 4    4998414  air conditioning,closet,coffee/tea maker,desk,...
# 1    2314283  air conditioning,alarm clock,coffee/tea maker,...
# 5      45042  air conditioning,closet,coffee/tea maker,daily...
# 3     399328  air conditioning,carpeting,closet,coffee/tea m...
# 0     789357  air conditioning,alarm clock,carpeting,closet,...
#
#                                    roomtype  \
# 4                       Executive Apartment
# 1                                    Family
# 5                   Two Bedroom Family Room
# 3                                    Family
# 0   Basic Family Room with Shared Bathroom
#
#                                      ratedescription  \
# 4  Room size: 18 m²/194 ft², Non-smoking, Shower,...
# 1  Room size: 20 m²/215 ft², Non-smoking, Shower,...
# 5  Room size: 60 m²/646 ft², Lake view, Non-smoki...
# 3  Room size: 15 m²/161 ft², Street view, Non-smo...
# 0  Room size: 20 m²/215 ft², Non-smoking, Shared ...
#
#                                            hotelname                 address  \
# 4                               Millenium Apartments  28-30 Rivington Street
# 1               Comfort Inn St Pancras - Kings Cross   2-5 St. Chad's Street
# 5  DoubleTree by Hilton Hotel London - Docklands ...  265 Rotherhithe Street
# 3                                     Dockside Hotel        55 Sutton Street
# 0                                     Princess Hotel     35-39 Argyle Street
#
#      city         country propertytype  starrating   latitude  longitude  \
# 4  london  United Kingdom       Hotels           4  51.525899  -0.081915
# 1  london  United Kingdom       Hotels           3  51.529598  -0.122300
# 5  london  United Kingdom       Hotels           4  51.504459  -0.033230
# 3  london  United Kingdom       Hotels           3  51.512666  -0.053458
# 0  london  United Kingdom       Hotels           2  51.528744  -0.123086
#
#    guests_no  distance  similarity  onsiterate currency  \
# 4          4  2.016404           0      170.13      USD
# 1          4  3.984763           2      175.39      USD
# 5          4  3.004195           0      329.45      USD
# 3          4  1.655028           0        0.00      USD
# 0          4  3.972849           2      114.99      USD
#
#         mealinclusiontype          var
# 4        No Complimentary     0.000000
# 1  Free breakfast for {4}  1054.239140
# 5  Free breakfast for {4}  4216.886471
# 3        No Complimentary  5943.097200
# 0        No Complimentary  6209.714024

# %% [markdown]
# After applying Optimum band formula and simmilarity index

# %%
optimum_band=pd.read_csv('/content/hotel_price_min_max - Formula.csv')

# %%
from math import sin, cos, sqrt, atan2, radians
import requests
R=6373.0#Earth's Radius
sw = stopwords.words('english')
lemm = WordNetLemmatizer()
def hybrid(address,city,number,features):
    features=features.lower()
    features_tokens=word_tokenize(features)
    f1_set = {w for w in features_tokens if not w in sw}
    f_set=set()
    for se in f1_set:
        f_set.add(lemm.lemmatize(se))
    data = {
    'key': '4519d076b432f5',
    'q': address,
    'format': 'json'}
    response = requests.get(url, params=data)
    dist=[]
    lat1,long1=response.json()[0]['lat'],response.json()[0]['lon']
    lat1=radians(float(lat1))
    long1=radians(float(long1))
    hybridbase=hotel
    #hybridbase=hotel[hotel['guests_no']==number]
    hybridbase['city']=hybridbase['city'].str.lower()
    hybridbase=hybridbase[hybridbase['city']==city.lower()]
    hybridbase.drop_duplicates(subset='hotelcode',inplace=True,keep='first')
    hybridbase=hybridbase.set_index(np.arange(hybridbase.shape[0]))
    for i in range(hybridbase.shape[0]):
        lat2=radians(hybridbase['latitude'][i])
        long2=radians(hybridbase['longitude'][i])
        dlon = long2 - long1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = R * c
        dist.append(distance)
    hybridbase['distance']=dist
    hybridbase=hybridbase[hybridbase['distance']<=5]
    hybridbase=hybridbase.set_index(np.arange(hybridbase.shape[0]))
    coss=[]
    for i in range(hybridbase.shape[0]):
        temp_tokens=word_tokenize(hybridbase['roomamenities'][i])
        temp1_set={w for w in temp_tokens if not w in sw}
        temp_set=set()
        for se in temp1_set:
            temp_set.add(lemm.lemmatize(se))
        rvector = temp_set.intersection(f_set)
        coss.append(len(rvector))
    hybridbase['similarity']=coss
    return hybridbase.sort_values(by='similarity',ascending=False)

def price_band_based(address,city,number,features):
    h=hybrid(address,city,number,features)
    price_band=pd.merge(h,optimum_band,left_on=['hotelcode'],right_on=['hotelcode'],how='inner')
    price_band=pd.merge(price_band,hotel_cost,left_on=['hotelcode'],right_on=['hotelcode'],how='inner')
    del price_band['min']
    del price_band['max']
    del price_band['Diff_Min']
    del price_band['Diff_Max']
    del price_band['currency']
    del price_band['country']
    del price_band['propertytype']
    del price_band['starrating']
    del price_band['latitude']
    del price_band['longitude']
    del price_band['guests_no']
    del price_band['var']
    price_band=price_band[price_band['Score']<=0.5]
    price_band=price_band[price_band['maxoccupancy']>=number]
    return price_band

# %%
price_band_based("Tower of London",'London',4,'I need an alarm clock and a kettle flask.').head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     hotelcode                                      roomamenities  \
# 12     789357  air conditioning,alarm clock,carpeting,closet,...
# 17    2314283  air conditioning,alarm clock,coffee/tea maker,...
# 23    4453863  air conditioning,alarm clock,blackout curtains...
# 38     148900  air conditioning,alarm clock,carpeting,closet,...
# 87      84774  air conditioning,coffee/tea maker,daily housek...
#
#               roomtype                                    ratedescription  \
# 12  Standard Twin Room  Room size: 15 m²/161 ft², Non-smoking, Shower,...
# 17              Single  Room size: 20 m²/215 ft², Non-smoking, Shower,...
# 23        Studio Suite  Room size: 24 m²/258 ft², Street view, Non-smo...
# 38     Standard Single  City view, Non-smoking, Shared bathroom, 1 sin...
# 87  Standard Quad Room  Room size: 20 m²/215 ft², Balcony/terrace, Non...
#
#                                hotelname                             address  \
# 12                        Princess Hotel                 35-39 Argyle Street
# 17  Comfort Inn St Pancras - Kings Cross               2-5 St. Chad's Street
# 23    South Point Suites - London Bridge                   Bermondsey Street
# 38   Central Hotel London - King's Cross  16 - 18 Argyle Street, Kings Cross
# 87                         Huttons Hotel                 53-57 Belgrave Road
#
#       city  distance  similarity  Score  onsiterate  maxoccupancy  \
# 12  london  3.972849           2   0.16      114.99             4
# 17  london  3.984763           2   0.14      175.39             4
# 23  london  1.110365           2   0.26      187.95             4
# 38  london  4.045245           2   0.10      163.67             4
# 87  london  4.726689           0   0.16        0.00             4
#
#          mealinclusiontype
# 12        No Complimentary
# 17  Free breakfast for {4}
# 23        No Complimentary
# 38  Free breakfast for {4}
# 87        No Complimentary

# %% [markdown]
# After all these a reccommender system is made which considers the following features while recommending
#
# 1. Closness to location
# 2. Number of guests
# 3. Onsite Rate
# 4. Credibility of the hotel
# 5. Room Ammenities
# 6. Complimentary gifts(Like Free Meals,Take aways)
# 7. Optimum price band
# 8. Any special requests the customer needs(Using NLTK search engines)

# %%
import pickle
Pkl_Filename = "Pickle_RL_Model.pkl"  
with open(Pkl_Filename, 'wb') as file:  
    pickle.dump(price_band_based, file)
